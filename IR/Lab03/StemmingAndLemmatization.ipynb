# %%
import nltk

from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords


from nltk.tokenize import word_tokenize, wordpunct_tokenize

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mikol\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\mikol\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mikol\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mikol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# When working with a text you have to take into account families of words e.g. dog, dogs, doggy. The most popular techniques helping to deal with this issue are lemmatization and stemming. Both are special cases of normalization. They identify a canonical representative for a set of related word forms.
#
# The goal of both stemming and lemmatization is to reduce inflectional forms and sometimes derivationally related forms of a word to a common base form.
# However, the two words differ in their flavor. Stemming usually refers to a crude heuristic process that chops off the ends of words in the hope of achieving this goal correctly most of the time, and often includes the removal of derivational affixes. Lemmatization usually refers to doing things properly with the use of a vocabulary and morphological analysis of words, normally aiming to remove inflectional endings only and to return the base or dictionary form of a word, which is known as the lemma.

# %%
porter = PorterStemmer()
lancaster = LancasterStemmer()
wordnet = WordNetLemmatizer()

# %%
print("{:15}{:15}{:15}{:15}".format("Word","Porter","Lancaster","WordNet"))
for word in ["was", "cats", "played", "mechanical", "friend", "friendship"]:
    print("{:15}{:15}{:15}{}".format(word, porter.stem(word), lancaster.stem(word), wordnet.lemmatize(word, pos="v")))
# Out:
# Word           Porter         Lancaster      WordNet
# was            wa             was            be
# cats           cat            cat            cat
# played         play           play           play
# mechanical     mechan         mech           mechanical
# friend         friend         friend         friend
# friendship     friendship     friend         friendship

# %%
text = """Poznań University of Technology, PUT (Polish name: Politechnika Poznańska) is a university in Poznań, 
Poland. Poznań University of Technology is known as one of the best technical universities in Poland. URAP 
ranked PUT as in top 6% of world universities and Webometrics ranked it at no. 842 in the world by Google 
citations for the year 2015. In 1995 it became the first Polish university to become a member of the Conference 
of European Schools for Advanced Engineering Education and Research (CESAER), an organization comprising the best 
technical universities in Europe. The university is also a member of the Socrates-Erasmus programme for exchange 
students from all over Europe, promoting advanced engineering and a European dimension. The university is home to 
many organizations and student circles, and the radio station Afera 98.6 MHz. The university has over 
21,000 students and over 1100 academic staffs.""".replace('\n',' ')

# %%
porter.stem(text)
# Out:
# 'poznań university of technology, put (polish name: politechnika poznańska) is a university in poznań,  poland. poznań university of technology is known as one of the best technical universities in poland. urap  ranked put as in top 6% of world universities and webometrics ranked it at no. 842 in the world by google  citations for the year 2015. in 1995 it became the first polish university to become a member of the conference  of european schools for advanced engineering education and research (cesaer), an organization comprising the best  technical universities in europe. the university is also a member of the socrates-erasmus programme for exchange  students from all over europe, promoting advanced engineering and a european dimension. the university is home to  many organizations and student circles, and the radio station afera 98.6 mhz. the university has over  21,000 students and over 1100 academic staffs.'

# %% [markdown]
# As a first step, we have to transform a string into a list of words. It's not as trivial as you might think. Thankfully there are libraries with such functions already implemented.

# %%
word_tokenize(text), len(word_tokenize(text))
# Out:
# (['Poznań',
#   'University',
#   'of',
#   'Technology',
#   ',',
#   'PUT',
#   '(',
#   'Polish',
#   'name',
#   ':',
#   'Politechnika',
#   'Poznańska',
#   ')',
#   'is',
#   'a',
#   'university',
#   'in',
#   'Poznań',
#   ',',
#   'Poland',
#   '.',
#   'Poznań',
#   'University',
#   'of',
#   'Technology',
#   'is',
#   'known',
#   'as',
#   'one',
#   'of',
#   'the',
#   'best',
#   'technical',
#   'universities',
#   'in',
#   'Poland',
#   '.',
#   'URAP',
#   'ranked',
#   'PUT',
#   'as',
#   'in',
#   'top',
#   '6',
#   '%',
#   'of',
#   'world',
#   'universities',
#   'and',
#   'Webometrics',
#   'ranked',
#   'it',
#   'at',
#   'no',
#   '.',
#   '842',
#   'in',
#   'the',
#   'world',
#   'by',
#   'Google',
#   'citations',
#   'for',
#   'the',
#   'year',
#   '2015',
#   '.',
#   'In',
#   '1995',
#   'it',
#   'became',
#   'the',
#   'first',
#   'Polish',
#   'university',
#   'to',
#   'become',
#   'a',
#   'member',
#   'of',
#   'the',
#   'Conference',
#   'of',
#   'European',
#   'Schools',
#   'for',
#   'Advanced',
#   'Engineering',
#   'Education',
#   'and',
#   'Research',
#   '(',
#   'CESAER',
#   ')',
#   ',',
#   'an',
#   'organization',
#   'comprising',
#   'the',
#   'best',
#   'technical',
#   'universities',
#   'in',
#   'Europe',
#   '.',
#   'The',
#   'university',
#   'is',
#   'also',
#   'a',
#   'member',
#   'of',
#   'the',
#   'Socrates-Erasmus',
#   'programme',
#   'for',
#   'exchange',
#   'students',
#   'from',
#   'all',
#   'over',
#   'Europe',
#   ',',
#   'promoting',
#   'advanced',
#   'engineering',
#   'and',
#   'a',
#   'European',
#   'dimension',
#   '.',
#   'The',
#   'university',
#   'is',
#   'home',
#   'to',
#   'many',
#   'organizations',
#   'and',
#   'student',
#   'circles',
#   ',',
#   'and',
#   'the',
#   'radio',
#   'station',
#   'Afera',
#   '98.6',
#   'MHz',
#   '.',
#   'The',
#   'university',
#   'has',
#   'over',
#   '21,000',
#   'students',
#   'and',
#   'over',
#   '1100',
#   'academic',
#   'staffs',
#   '.'],
#  162)

# %%
wordpunct_tokenize(text), len(wordpunct_tokenize(text))
# Out:
# (['Poznań',
#   'University',
#   'of',
#   'Technology',
#   ',',
#   'PUT',
#   '(',
#   'Polish',
#   'name',
#   ':',
#   'Politechnika',
#   'Poznańska',
#   ')',
#   'is',
#   'a',
#   'university',
#   'in',
#   'Poznań',
#   ',',
#   'Poland',
#   '.',
#   'Poznań',
#   'University',
#   'of',
#   'Technology',
#   'is',
#   'known',
#   'as',
#   'one',
#   'of',
#   'the',
#   'best',
#   'technical',
#   'universities',
#   'in',
#   'Poland',
#   '.',
#   'URAP',
#   'ranked',
#   'PUT',
#   'as',
#   'in',
#   'top',
#   '6',
#   '%',
#   'of',
#   'world',
#   'universities',
#   'and',
#   'Webometrics',
#   'ranked',
#   'it',
#   'at',
#   'no',
#   '.',
#   '842',
#   'in',
#   'the',
#   'world',
#   'by',
#   'Google',
#   'citations',
#   'for',
#   'the',
#   'year',
#   '2015',
#   '.',
#   'In',
#   '1995',
#   'it',
#   'became',
#   'the',
#   'first',
#   'Polish',
#   'university',
#   'to',
#   'become',
#   'a',
#   'member',
#   'of',
#   'the',
#   'Conference',
#   'of',
#   'European',
#   'Schools',
#   'for',
#   'Advanced',
#   'Engineering',
#   'Education',
#   'and',
#   'Research',
#   '(',
#   'CESAER',
#   '),',
#   'an',
#   'organization',
#   'comprising',
#   'the',
#   'best',
#   'technical',
#   'universities',
#   'in',
#   'Europe',
#   '.',
#   'The',
#   'university',
#   'is',
#   'also',
#   'a',
#   'member',
#   'of',
#   'the',
#   'Socrates',
#   '-',
#   'Erasmus',
#   'programme',
#   'for',
#   'exchange',
#   'students',
#   'from',
#   'all',
#   'over',
#   'Europe',
#   ',',
#   'promoting',
#   'advanced',
#   'engineering',
#   'and',
#   'a',
#   'European',
#   'dimension',
#   '.',
#   'The',
#   'university',
#   'is',
#   'home',
#   'to',
#   'many',
#   'organizations',
#   'and',
#   'student',
#   'circles',
#   ',',
#   'and',
#   'the',
#   'radio',
#   'station',
#   'Afera',
#   '98',
#   '.',
#   '6',
#   'MHz',
#   '.',
#   'The',
#   'university',
#   'has',
#   'over',
#   '21',
#   ',',
#   '000',
#   'students',
#   'and',
#   'over',
#   '1100',
#   'academic',
#   'staffs',
#   '.'],
#  167)

# %%
for x in word_tokenize(text):
    print("{:20} - {:20}".format(x, porter.stem(x)))
# Out:
# Poznań               - poznań
# University           - univers
# of                   - of
# Technology           - technolog
# ,                    - ,
# PUT                  - put
# (                    - (
# Polish               - polish
# name                 - name
# :                    - :
# Politechnika         - politechnika
# Poznańska            - poznańska
# )                    - )
# is                   - is
# a                    - a
# university           - univers
# in                   - in
# Poznań               - poznań
# ,                    - ,
# Poland               - poland
# .                    - .
# Poznań               - poznań
# University           - univers
# of                   - of
# Technology           - technolog
# is                   - is
# known                - known
# as                   - as
# one                  - one
# of                   - of
# the                  - the
# best                 - best
# technical            - technic
# universities         - univers
# in                   - in
# Poland               - poland
# .                    - .
# URAP                 - urap
# ranked               - rank
# PUT                  - put
# as                   - as
# in                   - in
# top                  - top
# 6                    - 6
# %                    - %
# of                   - of
# world                - world
# universities         - univers
# and                  - and
# Webometrics          - webometr
# ranked               - rank
# it                   - it
# at                   - at
# no                   - no
# .                    - .
# 842                  - 842
# in                   - in
# the                  - the
# world                - world
# by                   - by
# Google               - googl
# citations            - citat
# for                  - for
# the                  - the
# year                 - year
# 2015                 - 2015
# .                    - .
# In                   - in
# 1995                 - 1995
# it                   - it
# became               - becam
# the                  - the
# first                - first
# Polish               - polish
# university           - univers
# to                   - to
# become               - becom
# a                    - a
# member               - member
# of                   - of
# the                  - the
# Conference           - confer
# of                   - of
# European             - european
# Schools              - school
# for                  - for
# Advanced             - advanc
# Engineering          - engin
# Education            - educ
# and                  - and
# Research             - research
# (                    - (
# CESAER               - cesaer
# )                    - )
# ,                    - ,
# an                   - an
# organization         - organ
# comprising           - compris
# the                  - the
# best                 - best
# technical            - technic
# universities         - univers
# in                   - in
# Europe               - europ
# .                    - .
# The                  - the
# university           - univers
# is                   - is
# also                 - also
# a                    - a
# member               - member
# of                   - of
# the                  - the
# Socrates-Erasmus     - socrates-erasmu
# programme            - programm
# for                  - for
# exchange             - exchang
# students             - student
# from                 - from
# all                  - all
# over                 - over
# Europe               - europ
# ,                    - ,
# promoting            - promot
# advanced             - advanc
# engineering          - engin
# and                  - and
# a                    - a
# European             - european
# dimension            - dimens
# .                    - .
# The                  - the
# university           - univers
# is                   - is
# home                 - home
# to                   - to
# many                 - mani
# organizations        - organ
# and                  - and
# student              - student
# circles              - circl
# ,                    - ,
# and                  - and
# the                  - the
# radio                - radio
# station              - station
# Afera                - afera
# 98.6                 - 98.6
# MHz                  - mhz
# .                    - .
# The                  - the
# university           - univers
# has                  - ha
# over                 - over
# 21,000               - 21,000
# students             - student
# and                  - and
# over                 - over
# 1100                 - 1100
# academic             - academ
# staffs               - staff
# .                    - .

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %% [markdown]
# ## Task
# Write function which takes string as input and returns list of stems for reasonable words. Filter out stop words and non-words.

# %%
stop_words = set(stopwords.words('english'))

def custom_stemmer(string):
    """
    Takes a string as input and returns a list of stems for meaningful words.
    Filters out stopwords, punctuation, and non-alphabetic tokens.
    """
    tokens = word_tokenize(string.lower())
    stems = []
    for token in tokens:
        if token.isalpha() and token not in stop_words:
            stem = porter.stem(token)
            stems.append(stem)
    return stems

# %%
text = """Poznań University of Technology is known as one of the best technical universities in Poland.
          It has over 21,000 students and a great reputation in Europe."""

print(custom_stemmer(text))
# Out:
# ['poznań', 'univers', 'technolog', 'known', 'one', 'best', 'technic', 'univers', 'poland', 'student', 'great', 'reput', 'europ']

# %% [markdown]
# ## Task
# Convert a date of yyyy-mm-dd format to dd.mm.yyyy format using regular expresions

# %%
import re

s = ["1985-12-4",
    "asd 12-132-133",
    "Afs!@#-2055-12-12",
    "02-03-2020",
    "Is it a date 2012-11-01?"]

# %% [markdown]
# The following output is expected:
#
# 4.12.1985<br>
# asd 12-132-133<br>
# Afs!@#-12.12.2055<br>
# 02-03-2020<br>
# Is it a date 01.11.2012?<br>
#
# Use re.sub function

# %%
for x in s:
    print(re.sub(r'(\d+)-(\d+).*', r'first number: \g<1>; second number: \g<2>', x))
# Out:
# first number: 1985; second number: 12
# asd first number: 12; second number: 132
# Afs!@#-first number: 2055; second number: 12
# first number: 02; second number: 03
# Is it a date first number: 2012; second number: 11

# %%
# pattern: 4 digits (year) - 1-2 digits (month) - 1-2 digits (day)
pattern = r'(\d{4})-(\d{1,2})-(\d{1,2})'

# replace with: day.month.year
for x in s:
    converted = re.sub(pattern, r'\3.\2.\1', x)
    print(converted)
# Out:
# 4.12.1985
# asd 12-132-133
# Afs!@#-12.12.2055
# 02-03-2020
# Is it a date 01.11.2012?

# %% [markdown]
# # OCR

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:/Program Files/Tesseract-OCR/tesseract.exe"
from PIL import Image
import numpy as np
import cv2
import requests
from io import BytesIO

# %%
url = "https://i.ibb.co/8d564bB/example-01.png"

response = requests.get(url)
img = Image.open(BytesIO(response.content))

img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x250>

# %%
print(pytesseract.image_to_string(img))
# Out:
# Noisyimage
# to test
# Tesseract OCR

# %%
url = "https://i.ibb.co/n63mZfb/example-02.png"
response = requests.get(url)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x250>

# %%
print(pytesseract.image_to_string(img))
# Out:
# _ Tesseract Will
# Fail With Noisy
# _ Backgrounds —

# %% [markdown]
# ## Task
# Read perfectly text from example_02

# %%
# Convert to OpenCV format
img_cv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)

# --- Step 1: Convert to grayscale
gray = cv2.cvtColor(img_cv, cv2.COLOR_BGR2GRAY)

# --- Step 2: Remove noise and smooth
gray = cv2.medianBlur(gray, 3)

# --- Step 3: Threshold (convert to black text on white)
# Use Otsu’s binarization to separate text from background
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# --- Step 4: Optional - Invert (if text is white on dark)
# thresh = cv2.bitwise_not(thresh)

# --- Step 5: Enlarge text slightly to help OCR
thresh = cv2.resize(thresh, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_LINEAR)

# --- Step 6: OCR with proper configuration
custom_config = r'--oem 3 --psm 6'  # 3 = default LSTM OCR engine, 6 = assume a block of text
text = pytesseract.image_to_string(thresh, config=custom_config)

print(text)
# Out:
# Tesseract Will
# Fail With Noisy
# Backgrounds

# %%
response = requests.get("https://i.ibb.co/1ffsFkx/vin.png")
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x121>

# %%
print(pytesseract.image_to_string(img))

# %% [markdown]
# ## Task 5
# Read nearly perfectly text from vin.png, 1 error allowed (missing char, additional char, wrong char), 0/O is not an error

# %%
# Convert to OpenCV format
img_cv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)

# Step 1 & 2: Grayscale + Gaussian Blur
gray = cv2.cvtColor(img_cv, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Step 3: Adaptive Thresholding
thresh = cv2.adaptiveThreshold(
    blurred, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY_INV, 21, 13
)

# Step 4a: Initial Dilation
kernel_dilate_initial = np.ones((2, 2), np.uint8)
dilated_initial = cv2.dilate(thresh, kernel_dilate_initial, iterations=1)

# Step 4b: Morphological Opening (remove small noise)
kernel_open = np.ones((3, 3), np.uint8)
opened = cv2.morphologyEx(dilated_initial, cv2.MORPH_OPEN, kernel_open)

# Step 4c: Final Dilation (thicken text slightly)
kernel_dilate_final = np.ones((2, 2), np.uint8)
final_dilated = cv2.dilate(opened, kernel_dilate_final, iterations=1)

# Step 5: Enlarge for OCR
final_image = cv2.resize(final_dilated, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_LINEAR)

# Step 6: OCR
custom_config = r'--oem 3 --psm 8 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'
text = pytesseract.image_to_string(final_image, config=custom_config)

# Step 7: Clean output
cleaned_text = "".join(filter(str.isalnum, text)).strip()
print(cleaned_text if cleaned_text else "[No text detected]")
# Out:
# MRHRW5810KP10217
